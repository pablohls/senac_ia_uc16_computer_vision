# %%
from ultralytics import YOLO

# %%
# Load pretrained model
model = YOLO("yolo26n.pt")

# %%
# Train the model on Construction-PPE dataset
model.train(data="/home/senacgoon.local/202473567/Projects/senac_ia_uc_16_computer_vision/data/images/construction_ppe.yaml", epochs=10, imgsz=640)
